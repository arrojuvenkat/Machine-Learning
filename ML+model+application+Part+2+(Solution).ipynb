# %% [markdown]
# # Scroll down to get the QUIZ 5 solutions.

# %% [markdown]
# # QUIZ 1: Solution

# %% [markdown]
# # Load Data

# %%
import pandas as pd

# Replace 'your_excel_file.xlsx' with the path to your Excel file
excel_file = 'sales data.xlsx'

# Load Excel data into a pandas DataFrame
df = pd.read_excel(excel_file)

# Now, you can work with the data in the 'df' DataFrame
# For example, you can print the first few rows of the DataFrame
df.head()
# Out:
#     country  order_value_EUR       cost                 date     category  \
# 0    Sweden         98320.37   77722.25            8/23/2020        Games
# 1    France         46296.26   40319.41            5/15/2020        Games
# 2  Portugal        140337.34  115708.14  2020-04-09 00:00:00   Appliances
# 3    France        203604.46  175344.16            6/26/2019  Electronics
# 4        UK         63979.04   56032.84           10/22/2019        Games
#
#      customer_name    sales_manager            sales_rep device_type  \
# 0   Konopelski LLC     Maxie Marrow   Tarrah Castelletti      Tablet
# 1       Wisoky Inc    Othello Bowes  Amelina Piscopiello      Tablet
# 2    Hegmann Group  Celine Tumasian        Corene Shirer          PC
# 3  Kirlin and Sons    Othello Bowes         Crysta Halls      Mobile
# 4   Schoen-Keeling  Jessamine Apark   Genevra Charrisson          PC
#
#      order_id
# 0  70-0511466
# 1  77-3489084
# 2  65-8218141
# 3  29-5478106
# 4  27-3437546

# %% [markdown]
# # Missing Values

# %%
# Check for missing values in the entire DataFrame
missing_values = df.isnull().sum()

# To check for missing values in a specific column, you can use:
# missing_values = df['column_name'].isnull().sum()

# Print the columns with missing values and their respective counts
print("Missing Values:")
print(missing_values[missing_values > 0])
# Out:
# Missing Values:
# order_value_EUR    5
# device_type        5
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

target_column = 'order_value_EUR'

# Create a SimpleImputer instance to impute missing values with a strategy (e.g., 'mean', 'median', 'most_frequent')
# Other strategies include 'constant' to replace missing values with a constant value
imputer = SimpleImputer(strategy='median')

# Fit the imputer on the selected column and transform it to impute missing values
df[target_column] = imputer.fit_transform(df[[target_column]])

# %%
df.isnull().sum()
# Out:
# country            0
# order_value_EUR    0
# cost               0
# date               0
# category           0
# customer_name      0
# sales_manager      0
# sales_rep          0
# device_type        5
# order_id           0
# dtype: int64

# %%
df.device_type
# Out:
# 0       Tablet
# 1       Tablet
# 2           PC
# 3       Mobile
# 4           PC
#          ...
# 996         PC
# 997     Tablet
# 998     Tablet
# 999         PC
# 1000        PC
# Name: device_type, Length: 1001, dtype: object

# %%
target_column = 'device_type'

# Create a SimpleImputer instance to impute missing values with a strategy (e.g., 'mean', 'median', 'most_frequent')
# Other strategies include 'constant' to replace missing values with a constant value
imputer = SimpleImputer(strategy='most_frequent')

# Fit the imputer on the selected column and transform it to impute missing values
df[target_column] = imputer.fit_transform(df[[target_column]])

# %%
df.isnull().sum()
# Out:
# country            0
# order_value_EUR    0
# cost               0
# date               0
# category           0
# customer_name      0
# sales_manager      0
# sales_rep          0
# device_type        0
# order_id           0
# dtype: int64

# %% [markdown]
# # Inconsistent Values

# %%
df.dtypes
# Out:
# country             object
# order_value_EUR    float64
# cost                object
# date                object
# category            object
# customer_name       object
# sales_manager       object
# sales_rep           object
# device_type         object
# order_id            object
# dtype: object

# %%
# Sample variable containing mixed data
mixed_data = df['cost']

# Create an empty list to store non-numeric values
non_numeric_values = []

# Iterate through the elements in the variable
for value in mixed_data:
    if isinstance(value, str) and not value.isnumeric():
        non_numeric_values.append(value)

# Print the non-numeric values
print("Non-Numeric Values:")
print(non_numeric_values)
# Out:
# Non-Numeric Values:
# ['XXX']

# %%
mask = (df['cost'] == 'XXX')

# Remove rows that match the mask
df = df[~mask]

# %% [markdown]
# # Data Types

# %%
df['cost'] = df['cost'].astype(float)

# Print the DataFrame with the corrected data type
print(df.dtypes)
# Out:
# country             object
# order_value_EUR    float64
# cost               float64
# date                object
# category            object
# customer_name       object
# sales_manager       object
# sales_rep           object
# device_type         object
# order_id            object
# dtype: object

# %%
df['date'] = df['date'].astype('datetime64')

# %%
df.dtypes
# Out:
# country                    object
# order_value_EUR           float64
# cost                      float64
# date               datetime64[ns]
# category                   object
# customer_name              object
# sales_manager              object
# sales_rep                  object
# device_type                object
# order_id                   object
# dtype: object

# %%
df.head()
# Out:
#     country  order_value_EUR       cost       date     category  \
# 0    Sweden         98320.37   77722.25 2020-08-23        Games
# 1    France         46296.26   40319.41 2020-05-15        Games
# 2  Portugal        140337.34  115708.14 2020-04-09   Appliances
# 3    France        203604.46  175344.16 2019-06-26  Electronics
# 4        UK         63979.04   56032.84 2019-10-22        Games
#
#      customer_name    sales_manager            sales_rep device_type  \
# 0   Konopelski LLC     Maxie Marrow   Tarrah Castelletti      Tablet
# 1       Wisoky Inc    Othello Bowes  Amelina Piscopiello      Tablet
# 2    Hegmann Group  Celine Tumasian        Corene Shirer          PC
# 3  Kirlin and Sons    Othello Bowes         Crysta Halls      Mobile
# 4   Schoen-Keeling  Jessamine Apark   Genevra Charrisson          PC
#
#      order_id
# 0  70-0511466
# 1  77-3489084
# 2  65-8218141
# 3  29-5478106
# 4  27-3437546

# %% [markdown]
# # Duplicates Data

# %%
# Identify duplicate rows based on all columns
duplicates = df[df.duplicated()]

# Print duplicate rows
print("Duplicate Rows:")
duplicates
# Out:
# Duplicate Rows:
#    country  order_value_EUR      cost       date category   customer_name  \
# 23      UK         63979.04  56032.84 2019-10-22    Games  Schoen-Keeling
#
#       sales_manager           sales_rep device_type    order_id
# 23  Jessamine Apark  Genevra Charrisson          PC  27-3437546

# %%
# Remove duplicate rows, keeping the first occurrence
df_no_duplicates = df.drop_duplicates()

# Print the DataFrame without duplicates
print("DataFrame without Duplicates:")
df_no_duplicates
# Out:
# DataFrame without Duplicates:
#           country  order_value_EUR       cost       date     category  \
# 0          Sweden         98320.37   77722.25 2020-08-23        Games
# 1          France         46296.26   40319.41 2020-05-15        Games
# 2        Portugal        140337.34  115708.14 2020-04-09   Appliances
# 3          France        203604.46  175344.16 2019-06-26  Electronics
# 4              UK         63979.04   56032.84 2019-10-22        Games
# ...           ...              ...        ...        ...          ...
# 996        France         69126.50   55902.60 2019-08-12  Electronics
# 997        France        140943.88  120633.87 2020-05-28   Appliances
# 998        France        124784.67  106853.11 2020-05-22  Electronics
# 999       Germany         61968.26   50690.04 2020-12-27  Electronics
# 1000  Netherlands        172453.10  145688.38 2020-06-24     Outdoors
#
#                          customer_name    sales_manager            sales_rep  \
# ...

# %%
cleaned_data = df_no_duplicates

# %%
cleaned_data.head()
# Out:
#     country  order_value_EUR       cost       date     category  \
# 0    Sweden         98320.37   77722.25 2020-08-23        Games
# 1    France         46296.26   40319.41 2020-05-15        Games
# 2  Portugal        140337.34  115708.14 2020-04-09   Appliances
# 3    France        203604.46  175344.16 2019-06-26  Electronics
# 4        UK         63979.04   56032.84 2019-10-22        Games
#
#      customer_name    sales_manager            sales_rep device_type  \
# 0   Konopelski LLC     Maxie Marrow   Tarrah Castelletti      Tablet
# 1       Wisoky Inc    Othello Bowes  Amelina Piscopiello      Tablet
# 2    Hegmann Group  Celine Tumasian        Corene Shirer          PC
# 3  Kirlin and Sons    Othello Bowes         Crysta Halls      Mobile
# 4   Schoen-Keeling  Jessamine Apark   Genevra Charrisson          PC
#
#      order_id
# 0  70-0511466
# 1  77-3489084
# 2  65-8218141
# 3  29-5478106
# 4  27-3437546

# %% [markdown]
# # QUIZ 2: Solution

# %% [markdown]
# # Data Sorting

# %%
df_sorted = df.sort_values(by='cost', ascending=True)

# %%
df_sorted
# Out:
#          country  order_value_EUR       cost       date     category  \
# 422       Sweden        15100.570   12113.68 2019-02-20        Games
# 275       France        16388.900   13430.70 2020-03-15  Electronics
# 17        Sweden        15817.050   13743.44 2019-10-03     Clothing
# 971  Netherlands       105357.645   14102.75 2020-07-02     Clothing
# 138       Sweden        17524.020   14122.61 2020-12-02        Books
# ..           ...              ...        ...        ...          ...
# 766       Sweden       325331.990  264592.51 2019-12-23        Games
# 242   Luxembourg       312928.720  270401.71 2019-12-12       Beauty
# 413  Netherlands       353925.060  287528.72 2020-04-12     Clothing
# 84       Ireland       361182.870  288368.40 2019-02-12        Books
# 986           UK       383996.760  304701.43 2019-12-19        Other
#
#                  customer_name    sales_manager           sales_rep  \
# 422  Murray, Reichel and Nolan     Maxie Marrow  Tarrah Castelletti
# ...

# %% [markdown]
# # Conditional Filtering

# %%
France_df = df[df['country'] == 'France']
France_df
# Out:
#     country  order_value_EUR       cost       date     category  \
# 1    France         46296.26   40319.41 2020-05-15        Games
# 3    France        203604.46  175344.16 2019-06-26  Electronics
# 7    France         96795.99   81395.75 2019-06-21   Appliances
# 16   France         65193.88   53113.45 2019-04-10       Beauty
# 18   France         54079.04   45031.62 2020-05-29        Games
# ..      ...              ...        ...        ...          ...
# 993  France        167072.72  135044.88 2019-10-21     Clothing
# 994  France        157932.84  134148.15 2020-01-31        Games
# 996  France         69126.50   55902.60 2019-08-12  Electronics
# 997  France        140943.88  120633.87 2020-05-28   Appliances
# 998  France        124784.67  106853.11 2020-05-22  Electronics
#
#                         customer_name  sales_manager            sales_rep  \
# 1                          Wisoky Inc  Othello Bowes  Amelina Piscopiello
# ...

# %%
France_Games_df = df[(df['country'] == 'France') & (df['category'] == 'Games')]
France_Games_df.head()
# Out:
#     country  order_value_EUR       cost       date category  \
# 1    France         46296.26   40319.41 2020-05-15    Games
# 18   France         54079.04   45031.62 2020-05-29    Games
# 50   France        149500.61  125401.11 2020-07-24    Games
# 104  France        146325.53  118333.46 2020-09-08    Games
# 137  France        133754.65  106147.69 2020-09-18    Games
#
#                     customer_name  sales_manager            sales_rep  \
# 1                      Wisoky Inc  Othello Bowes  Amelina Piscopiello
# 18   Lueilwitz, Kerluke and Lesch  Othello Bowes       Avrit Chanders
# 50              McGlynn-Bergstrom  Othello Bowes         Crysta Halls
# 104                   Stehr-Bogan  Othello Bowes         Crysta Halls
# 137              Armstrong-Little  Othello Bowes          Ora Grennan
#
#     device_type    order_id
# 1        Tablet  77-3489084
# 18           PC  15-6838362
# 50           PC  60-8646184
# 104          PC  95-8015610
# 137          PC  52-3150154

# %%
Not_France_df = df[df['country'] != 'France']
Not_France_df.head()
# Out:
#     country  order_value_EUR       cost       date    category  \
# 0    Sweden         98320.37   77722.25 2020-08-23       Games
# 2  Portugal        140337.34  115708.14 2020-04-09  Appliances
# 4        UK         63979.04   56032.84 2019-10-22       Games
# 5     Italy        127075.41  110924.13 2019-09-24    Clothing
# 6    Sweden         69681.43   55529.13 2020-01-25    Clothing
#
#         customer_name    sales_manager           sales_rep device_type  \
# 0      Konopelski LLC     Maxie Marrow  Tarrah Castelletti      Tablet
# 2       Hegmann Group  Celine Tumasian       Corene Shirer          PC
# 4      Schoen-Keeling  Jessamine Apark  Genevra Charrisson          PC
# 5    Labadie and Sons   Piggy Roscrigg      Joshua Prevost          PC
# 6  Romaguera-Dietrich     Maxie Marrow        Alyosha Meah          PC
#
#      order_id
# 0  70-0511466
# 2  65-8218141
# 4  27-3437546
# 5  57-6602854
# 6  78-3301264

# %% [markdown]
# # Data Merging

# %%
# Replace 'your_excel_file.xlsx' with the path to your Excel file
excel_file = 'Extra Variable.xlsx'

# Load Excel data into a pandas DataFrame
extra_vars = pd.read_excel(excel_file)

# Now, you can work with the data in the 'df' DataFrame
# For example, you can print the first few rows of the DataFrame
extra_vars.head()
# Out:
#      order_id  refund
# 0  70-0511466   43621
# 1  77-3489084   13385
# 2  65-8218141   69535
# 3  29-5478106   90064
# 4  57-6602854   61736

# %%
merged_df = cleaned_data.merge(extra_vars, on='order_id')
merged_df.head()
# Out:
#     country  order_value_EUR       cost       date     category  \
# 0    Sweden         98320.37   77722.25 2020-08-23        Games
# 1    France         46296.26   40319.41 2020-05-15        Games
# 2  Portugal        140337.34  115708.14 2020-04-09   Appliances
# 3    France        203604.46  175344.16 2019-06-26  Electronics
# 4        UK         63979.04   56032.84 2019-10-22        Games
#
#      customer_name    sales_manager            sales_rep device_type  \
# 0   Konopelski LLC     Maxie Marrow   Tarrah Castelletti      Tablet
# 1       Wisoky Inc    Othello Bowes  Amelina Piscopiello      Tablet
# 2    Hegmann Group  Celine Tumasian        Corene Shirer          PC
# 3  Kirlin and Sons    Othello Bowes         Crysta Halls      Mobile
# 4   Schoen-Keeling  Jessamine Apark   Genevra Charrisson          PC
#
#      order_id  refund
# 0  70-0511466   43621
# 1  77-3489084   13385
# 2  65-8218141   69535
# 3  29-5478106   90064
# 4  27-3437546   24176

# %% [markdown]
# # Data Concatenating

# %%
# Replace 'your_excel_file.xlsx' with the path to your Excel file
excel_file = 'Extra Data.xlsx'

# Load Excel data into a pandas DataFrame
extra_data = pd.read_excel(excel_file)

# Now, you can work with the data in the 'df' DataFrame
# For example, you can print the first few rows of the DataFrame
extra_data.head()
# Out:
#     country  order_value_EUR      cost                 date    category  \
# 0    Sweden         17524.02  14122.61  2020-12-02 00:00:00       Books
# 1    France         64827.80  56043.63            1/20/2019  Appliances
# 2  Portugal         71620.08  62245.01  2019-05-02 00:00:00       Books
# 3  Portugal         74532.02  59752.32  2020-02-04 00:00:00      Beauty
# 4  Portugal         78461.13  63537.82  2020-10-05 00:00:00  Appliances
#
#        customer_name    sales_manager           sales_rep device_type  \
# 0    Goldner-Dibbert     Maxie Marrow       Madelon Bront      Mobile
# 1   Gislason-Stanton    Othello Bowes   Maighdiln Upcraft          PC
# 2     Schoen-Keeling  Celine Tumasian  Smitty Culverhouse         NaN
# 3  Hessel-Stiedemann  Celine Tumasian        Aurelie Wren          PC
# 4  Hessel-Stiedemann  Celine Tumasian  Smitty Culverhouse      Mobile
#
#      order_id  refund
# 0  70-0511466    7964
# 1  62-3312495    4974
# 2  69-6259390    2809
# ...

# %%
final_df = pd.concat([merged_df, extra_data], ignore_index=True)
final_df
# Out:
#        country  order_value_EUR       cost                 date     category  \
# 0       Sweden         98320.37   77722.25  2020-08-23 00:00:00        Games
# 1       France         46296.26   40319.41  2020-05-15 00:00:00        Games
# 2     Portugal        140337.34  115708.14  2020-04-09 00:00:00   Appliances
# 3       France        203604.46  175344.16  2019-06-26 00:00:00  Electronics
# 4           UK         63979.04   56032.84  2019-10-22 00:00:00        Games
# ...        ...              ...        ...                  ...          ...
# 1004     Spain         84900.24   73701.90            7/14/2020     Clothing
# 1005   Finland        116563.40   92807.78            9/26/2019        Games
# 1006        UK        156585.22  126599.15            8/30/2020  Accessories
# 1007     Spain        178763.42  146621.76           12/22/2019        Games
# 1008  Portugal        296685.56  257480.34  2019-11-07 00:00:00     Clothing
#
# ...

# %% [markdown]
# # QUIZ 3: Solutions

# %% [markdown]
# # Feature engineering

# %%
final_df.head()
# Out:
#     country  order_value_EUR       cost                 date     category  \
# 0    Sweden         98320.37   77722.25  2020-08-23 00:00:00        Games
# 1    France         46296.26   40319.41  2020-05-15 00:00:00        Games
# 2  Portugal        140337.34  115708.14  2020-04-09 00:00:00   Appliances
# 3    France        203604.46  175344.16  2019-06-26 00:00:00  Electronics
# 4        UK         63979.04   56032.84  2019-10-22 00:00:00        Games
#
#      customer_name    sales_manager            sales_rep device_type  \
# 0   Konopelski LLC     Maxie Marrow   Tarrah Castelletti      Tablet
# 1       Wisoky Inc    Othello Bowes  Amelina Piscopiello      Tablet
# 2    Hegmann Group  Celine Tumasian        Corene Shirer          PC
# 3  Kirlin and Sons    Othello Bowes         Crysta Halls      Mobile
# 4   Schoen-Keeling  Jessamine Apark   Genevra Charrisson          PC
#
#      order_id  refund
# 0  70-0511466   43621
# 1  77-3489084   13385
# 2  65-8218141   69535
# ...

# %%
# Create a pivot table to calculate median sales and cost, and purchase frequency
pivot_table = final_df.pivot_table(index='customer_name',
                             values=['order_value_EUR', 'cost'],
                             aggfunc={'order_value_EUR': 'median', 'cost': 'median', 'customer_name': 'count'})

# Rename columns for clarity
pivot_table.columns = ['Median Cost', 'Purchase Frequency', 'Median Sales']

# %%
sorted_pivot_table = pivot_table.sort_values(by = 'Purchase Frequency', ascending = False)
top_10 = sorted_pivot_table[0:10]
top_10
# Out:
#                                   Median Cost  Purchase Frequency  \
# customer_name
# Johns and Sons                       86694.33                 143
# Hessel-Stiedemann                    79127.71                  57
# Swaniawski, Runolfsson and Green     84690.35                  25
# Dickinson, Hyatt and Berge           85886.10                  24
# Murray, Reichel and Nolan            71501.10                  23
# Rowe, Hermiston and Kessler          66065.68                  22
# Larkin-Collier                      105025.33                  22
# Kihn Inc                             66742.15                  22
# Wisoky Inc                           94336.18                  21
# Tillman and Sons                     75839.40                  21
#
#                                   Median Sales
# customer_name
# Johns and Sons                      106115.850
# Hessel-Stiedemann                    95960.770
# Swaniawski, Runolfsson and Green    100094.970
# ...

# %%
top_10.index
# Out:
# Index(['Johns and Sons', 'Hessel-Stiedemann',
#        'Swaniawski, Runolfsson and Green', 'Dickinson, Hyatt and Berge',
#        'Murray, Reichel and Nolan', 'Rowe, Hermiston and Kessler',
#        'Larkin-Collier', 'Kihn Inc', 'Wisoky Inc', 'Tillman and Sons'],
#       dtype='object', name='customer_name')

# %%
# List of loyal customer names
loyal_customer_names = ['Johns and Sons', 'Hessel-Stiedemann', 'Swaniawski, Runolfsson and Green',
                        'Dickinson, Hyatt and Berge', 'Murray, Reichel and Nolan',
                        'Rowe, Hermiston and Kessler', 'Kihn Inc', 'Tillman and Sons',
                        'Wisoky Inc', 'Larkin-Collier']

# Function to assign "Loyal customer" or "Regular customer"
def customer_type(name):
    if name in loyal_customer_names:
        return "Loyal customer"
    else:
        return "Regular customer"

# Apply the function to create a new variable 'CustomerType'
final_df['CustomerType'] = final_df['customer_name'].apply(customer_type)

# %%
final_df.head()
# Out:
#     country  order_value_EUR       cost                 date     category  \
# 0    Sweden         98320.37   77722.25  2020-08-23 00:00:00        Games
# 1    France         46296.26   40319.41  2020-05-15 00:00:00        Games
# 2  Portugal        140337.34  115708.14  2020-04-09 00:00:00   Appliances
# 3    France        203604.46  175344.16  2019-06-26 00:00:00  Electronics
# 4        UK         63979.04   56032.84  2019-10-22 00:00:00        Games
#
#      customer_name    sales_manager            sales_rep device_type  \
# 0   Konopelski LLC     Maxie Marrow   Tarrah Castelletti      Tablet
# 1       Wisoky Inc    Othello Bowes  Amelina Piscopiello      Tablet
# 2    Hegmann Group  Celine Tumasian        Corene Shirer          PC
# 3  Kirlin and Sons    Othello Bowes         Crysta Halls      Mobile
# 4   Schoen-Keeling  Jessamine Apark   Genevra Charrisson          PC
#
#      order_id  refund      CustomerType
# 0  70-0511466   43621  Regular customer
# ...

# %%
final_df['CustomerType'].value_counts()
# Out:
# Regular customer    629
# Loyal customer      380
# Name: CustomerType, dtype: int64

# %%
# Convert the 'Date' column to a datetime type
final_df['date'] = pd.to_datetime(final_df['date'])

# Extract day, month, and year into new columns
final_df['Day'] = final_df['date'].dt.day
final_df['Month'] = final_df['date'].dt.month
final_df['Year'] = final_df['date'].dt.year

# %%
final_df.head()
# Out:
#     country  order_value_EUR       cost       date     category  \
# 0    Sweden         98320.37   77722.25 2020-08-23        Games
# 1    France         46296.26   40319.41 2020-05-15        Games
# 2  Portugal        140337.34  115708.14 2020-04-09   Appliances
# 3    France        203604.46  175344.16 2019-06-26  Electronics
# 4        UK         63979.04   56032.84 2019-10-22        Games
#
#      customer_name    sales_manager            sales_rep device_type  \
# 0   Konopelski LLC     Maxie Marrow   Tarrah Castelletti      Tablet
# 1       Wisoky Inc    Othello Bowes  Amelina Piscopiello      Tablet
# 2    Hegmann Group  Celine Tumasian        Corene Shirer          PC
# 3  Kirlin and Sons    Othello Bowes         Crysta Halls      Mobile
# 4   Schoen-Keeling  Jessamine Apark   Genevra Charrisson          PC
#
#      order_id  refund      CustomerType  Day  Month  Year
# 0  70-0511466   43621  Regular customer   23      8  2020
# ...

# %%
final_df['Year'].value_counts()
# Out:
# 2020    515
# 2019    494
# Name: Year, dtype: int64

# %% [markdown]
# # Extracting Day, Month, Year

# %%
# Convert the 'Date' column to a datetime type
final_df['date'] = pd.to_datetime(final_df['date'])

# Extract day, month, and year into new columns
final_df['Day'] = final_df['date'].dt.day
final_df['Month'] = final_df['date'].dt.month
final_df['Year'] = final_df['date'].dt.year

# %%
final_df.head()
# Out:
#     country  order_value_EUR       cost       date     category  \
# 0    Sweden         98320.37   77722.25 2020-08-23        Games
# 1    France         46296.26   40319.41 2020-05-15        Games
# 2  Portugal        140337.34  115708.14 2020-04-09   Appliances
# 3    France        203604.46  175344.16 2019-06-26  Electronics
# 4        UK         63979.04   56032.84 2019-10-22        Games
#
#      customer_name    sales_manager            sales_rep device_type  \
# 0   Konopelski LLC     Maxie Marrow   Tarrah Castelletti      Tablet
# 1       Wisoky Inc    Othello Bowes  Amelina Piscopiello      Tablet
# 2    Hegmann Group  Celine Tumasian        Corene Shirer          PC
# 3  Kirlin and Sons    Othello Bowes         Crysta Halls      Mobile
# 4   Schoen-Keeling  Jessamine Apark   Genevra Charrisson          PC
#
#      order_id  refund      CustomerType  Day  Month  Year
# 0  70-0511466   43621  Regular customer   23      8  2020
# ...

# %%
final_df['Year'].value_counts()
# Out:
# 2020    515
# 2019    494
# Name: Year, dtype: int64

# %% [markdown]
# # Feature Encoding

# %%
# Replace values in the 'CustomerType' column
final_df['CustomerType_encoded'] = final_df['CustomerType'].replace({'Loyal customer': 1, 'Regular customer': 0})

# %%
final_df.head()
# Out:
#     country  order_value_EUR       cost       date     category  \
# 0    Sweden         98320.37   77722.25 2020-08-23        Games
# 1    France         46296.26   40319.41 2020-05-15        Games
# 2  Portugal        140337.34  115708.14 2020-04-09   Appliances
# 3    France        203604.46  175344.16 2019-06-26  Electronics
# 4        UK         63979.04   56032.84 2019-10-22        Games
#
#      customer_name    sales_manager            sales_rep device_type  \
# 0   Konopelski LLC     Maxie Marrow   Tarrah Castelletti      Tablet
# 1       Wisoky Inc    Othello Bowes  Amelina Piscopiello      Tablet
# 2    Hegmann Group  Celine Tumasian        Corene Shirer          PC
# 3  Kirlin and Sons    Othello Bowes         Crysta Halls      Mobile
# 4   Schoen-Keeling  Jessamine Apark   Genevra Charrisson          PC
#
#      order_id  refund      CustomerType  Day  Month  Year  \
# 0  70-0511466   43621  Regular customer   23      8  2020
# ...

# %% [markdown]
# # Creating Dummy variable

# %%
# Create dummy variables for categorical columns
prep_df = pd.get_dummies(final_df, columns=['country', 'category', 'device_type'])

# %%
prep_df.head()
# Out:
#    order_value_EUR       cost       date    customer_name    sales_manager  \
# 0         98320.37   77722.25 2020-08-23   Konopelski LLC     Maxie Marrow
# 1         46296.26   40319.41 2020-05-15       Wisoky Inc    Othello Bowes
# 2        140337.34  115708.14 2020-04-09    Hegmann Group  Celine Tumasian
# 3        203604.46  175344.16 2019-06-26  Kirlin and Sons    Othello Bowes
# 4         63979.04   56032.84 2019-10-22   Schoen-Keeling  Jessamine Apark
#
#              sales_rep    order_id  refund      CustomerType  Day  ...  \
# 0   Tarrah Castelletti  70-0511466   43621  Regular customer   23  ...
# 1  Amelina Piscopiello  77-3489084   13385    Loyal customer   15  ...
# 2        Corene Shirer  65-8218141   69535  Regular customer    9  ...
# 3         Crysta Halls  29-5478106   90064  Regular customer   26  ...
# 4   Genevra Charrisson  27-3437546   24176  Regular customer   22  ...
#
#    category_Books  category_Clothing  category_Electronics  category_Games  \
# ...

# %% [markdown]
# # Feature Scaling

# %%
y = prep_df['refund']

# %%
prep_df.columns
# Out:
# Index(['order_value_EUR', 'cost', 'date', 'customer_name', 'sales_manager',
#        'sales_rep', 'order_id', 'refund', 'CustomerType', 'Day', 'Month',
#        'Year', 'CustomerType_encoded', 'country_Austria', 'country_Belgium',
#        'country_Bulgaria', 'country_Denmark', 'country_Finland',
#        'country_France', 'country_Germany', 'country_Ireland', 'country_Italy',
#        'country_Luxembourg', 'country_Netherlands', 'country_Portugal',
#        'country_Spain', 'country_Sweden', 'country_UK', 'category_Accessories',
#        'category_Appliances', 'category_Beauty', 'category_Books',
#        'category_Clothing', 'category_Electronics', 'category_Games',
#        'category_Other', 'category_Outdoors', 'category_Smartphones',
#        'device_type_Mobile', 'device_type_PC', 'device_type_Tablet'],
#       dtype='object')

# %%
# List of categorical variables to drop
variables_to_drop = ['date', 'customer_name', 'sales_manager', 'sales_rep', 'order_id', 'refund', 'CustomerType']

# Drop the specified columns
x = prep_df.drop(variables_to_drop, axis=1)

# %%
x.columns
# Out:
# Index(['order_value_EUR', 'cost', 'Day', 'Month', 'Year',
#        'CustomerType_encoded', 'country_Austria', 'country_Belgium',
#        'country_Bulgaria', 'country_Denmark', 'country_Finland',
#        'country_France', 'country_Germany', 'country_Ireland', 'country_Italy',
#        'country_Luxembourg', 'country_Netherlands', 'country_Portugal',
#        'country_Spain', 'country_Sweden', 'country_UK', 'category_Accessories',
#        'category_Appliances', 'category_Beauty', 'category_Books',
#        'category_Clothing', 'category_Electronics', 'category_Games',
#        'category_Other', 'category_Outdoors', 'category_Smartphones',
#        'device_type_Mobile', 'device_type_PC', 'device_type_Tablet'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Scale the numeric columns
scaled_data = scaler.fit_transform(x)

# %%
scaled_data
# Out:
# array([[-0.24271229, -0.32322742,  0.83856758, ..., -0.40966337,
#         -1.89376969,  3.55459353],
#        [-1.08746076, -1.0471347 , -0.07282565, ..., -0.40966337,
#         -1.89376969,  3.55459353],
#        [ 0.43954391,  0.41196441, -0.75637057, ..., -0.40966337,
#          0.52804732, -0.28132612],
#        ...,
#        [ 0.70337104,  0.62275272,  1.63603666, ..., -0.40966337,
#          0.52804732, -0.28132612],
#        [ 1.06349254,  1.01027712,  0.72464343, ..., -0.40966337,
#         -1.89376969,  3.55459353],
#        [ 2.97826913,  3.15587176, -0.98421888, ..., -0.40966337,
#          0.52804732, -0.28132612]])

# %% [markdown]
# # Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %%
# Split the data into training and testing sets
train_x, test_x, train_y, test_y = train_test_split(scaled_data, y, test_size=0.25, random_state=42)

# %% [markdown]
# # QUIZ 4: Solutions

# %% [markdown]
# # Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
# Initialize the Linear Regression model
model = LinearRegression()

# Train (fit) the model on the training data
model.fit(train_x, train_y)

# Make predictions on the test data
y_pred = model.predict(test_x)

# %%
# Calculate MAPE
def calculate_mape(test_y, y_pred):
    return np.mean(np.abs((test_y - y_pred) / test_y)) * 100

mape = calculate_mape(test_y, y_pred)

# %%
# Visualize y_pred against test_y
plt.scatter(y_pred, test_y, color='blue')

plt.xlabel('Prediction')
plt.ylabel('Actual')
plt.title('Linear Regression Prediction vs. Actual Data')

plt.show()

# %%
# Create a KDE plot to visualize the distribution of residuals
residuals = test_y - y_pred
sns.kdeplot(residuals, shade=True)
plt.xlabel('Residuals')
plt.ylabel('Density')
plt.title('Residuals Distribution (KDE Plot)')
plt.show()

# %%
# Print MAPE
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
# Out:
# Mean Absolute Percentage Error (MAPE): 35.86%

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
# Initialize the Decision Tree Regressor model
model_decTree = DecisionTreeRegressor()

# Train (fit) the model on the training data
model_decTree.fit(train_x, train_y)

# Make predictions on the test data
y_pred_decTree = model_decTree.predict(test_x)

# %%
mape_decTree = calculate_mape(test_y, y_pred_decTree)

# %%
# Visualize y_pred against test_y
plt.scatter(y_pred_decTree, test_y, color='blue')

plt.xlabel('Prediction')
plt.ylabel('Actual')
plt.title('Decision Tree Regression Prediction vs. Actual Data')

plt.show()

# %%
# Create a KDE plot to visualize the distribution of residuals
residuals = test_y - y_pred_decTree
sns.kdeplot(residuals, shade=True)
plt.xlabel('Residuals')
plt.ylabel('Density')
plt.title('Residuals Distribution (KDE Plot)')
plt.show()

# %%
# Print MAPE
print(f"Mean Absolute Percentage Error (MAPE): {mape_decTree:.2f}%")
# Out:
# Mean Absolute Percentage Error (MAPE): 10.97%

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Initialize the Random Forest Regressor model
model_rfreg = RandomForestRegressor()

# Train (fit) the model on the training data
model_rfreg.fit(train_x, train_y)

# Make predictions on the test data
y_pred_rfreg = model_rfreg.predict(test_x)

# %%
mape_rfreg = calculate_mape(test_y, y_pred_rfreg)

# %%
# Visualize y_pred against test_y
plt.scatter(y_pred_rfreg, test_y, color='blue')

plt.xlabel('Prediction')
plt.ylabel('Actual')
plt.title('Random Forest Regression Prediction vs. Actual Data')

plt.show()

# %%
# Create a KDE plot to visualize the distribution of residuals
residuals = test_y - y_pred_rfreg
sns.kdeplot(residuals, shade=True)
plt.xlabel('Residuals')
plt.ylabel('Density')
plt.title('Residuals Distribution (KDE Plot)')
plt.show()

# %%
# Print MAPE
print(f"Mean Absolute Percentage Error (MAPE): {mape_rfreg:.2f}%")
# Out:
# Mean Absolute Percentage Error (MAPE): 9.95%

# %% [markdown]
# # SVR Model

# %%
from sklearn.svm import SVR

# %%
# Initialize the Support Vector Regressor model
model_svr = SVR()

# Train (fit) the model on the training data
model_svr.fit(train_x, train_y)

# Make predictions on the test data
y_pred_svr = model_svr.predict(test_x)

# %%
mape_svr = calculate_mape(test_y, y_pred_svr)

# %%
# Visualize y_pred against test_y
plt.scatter(y_pred_svr, test_y, color='blue')

plt.xlabel('Prediction')
plt.ylabel('Actual')
plt.title('Support Vector Regression Prediction vs. Actual Data')

plt.show()

# %%
# Create a KDE plot to visualize the distribution of residuals
residuals = test_y - y_pred_svr
sns.kdeplot(residuals, shade=True)
plt.xlabel('Residuals')
plt.ylabel('Density')
plt.title('Residuals Distribution (KDE Plot)')
plt.show()

# %%
# Print MAPE
print(f"Mean Absolute Percentage Error (MAPE): {mape_svr:.2f}%")
# Out:
# Mean Absolute Percentage Error (MAPE): 152.87%

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb

# %%
# Initialize the XGBoost Regressor model
model_xgb = xgb.XGBRegressor()

# Train (fit) the model on the training data
model_xgb.fit(train_x, train_y)

# Make predictions on the test data
y_pred_xgb = model_xgb.predict(test_x)

# %%
mape_xgb = calculate_mape(test_y, y_pred_xgb)

# %%
# Visualize y_pred against test_y
plt.scatter(y_pred_xgb, test_y, color='blue')

plt.xlabel('Prediction')
plt.ylabel('Actual')
plt.title('XGBoost Regression Prediction vs. Actual Data')

plt.show()

# %%
# Create a KDE plot to visualize the distribution of residuals
residuals = test_y - y_pred_xgb
sns.kdeplot(residuals, shade=True)
plt.xlabel('Residuals')
plt.ylabel('Density')
plt.title('Residuals Distribution (KDE Plot)')
plt.show()

# %%
# Print MAPE
print(f"Mean Absolute Percentage Error (MAPE): {mape_xgb:.2f}%")
# Out:
# Mean Absolute Percentage Error (MAPE): 11.24%

# %% [markdown]
# # QUIZ 5: Solutions

# %% [markdown]
# ## Data Preprocessing Part 2

# %%
prep_df.head()
# Out:
#    order_value_EUR       cost       date    customer_name    sales_manager  \
# 0         98320.37   77722.25 2020-08-23   Konopelski LLC     Maxie Marrow
# 1         46296.26   40319.41 2020-05-15       Wisoky Inc    Othello Bowes
# 2        140337.34  115708.14 2020-04-09    Hegmann Group  Celine Tumasian
# 3        203604.46  175344.16 2019-06-26  Kirlin and Sons    Othello Bowes
# 4         63979.04   56032.84 2019-10-22   Schoen-Keeling  Jessamine Apark
#
#              sales_rep    order_id  refund      CustomerType  Day  ...  \
# 0   Tarrah Castelletti  70-0511466   43621  Regular customer   23  ...
# 1  Amelina Piscopiello  77-3489084   13385    Loyal customer   15  ...
# 2        Corene Shirer  65-8218141   69535  Regular customer    9  ...
# 3         Crysta Halls  29-5478106   90064  Regular customer   26  ...
# 4   Genevra Charrisson  27-3437546   24176  Regular customer   22  ...
#
#    category_Books  category_Clothing  category_Electronics  category_Games  \
# ...

# %%
y_cat = prep_df['CustomerType_encoded']

# %%
# List of categorical variables to drop
variables_to_drop = ['date', 'customer_name', 'sales_manager', 'sales_rep', 'order_id', 'CustomerType', 'CustomerType_encoded']

# Drop the specified columns
x_cat = prep_df.drop(variables_to_drop, axis=1)

# %%
x_cat.columns
# Out:
# Index(['order_value_EUR', 'cost', 'refund', 'Day', 'Month', 'Year',
#        'country_Austria', 'country_Belgium', 'country_Bulgaria',
#        'country_Denmark', 'country_Finland', 'country_France',
#        'country_Germany', 'country_Ireland', 'country_Italy',
#        'country_Luxembourg', 'country_Netherlands', 'country_Portugal',
#        'country_Spain', 'country_Sweden', 'country_UK', 'category_Accessories',
#        'category_Appliances', 'category_Beauty', 'category_Books',
#        'category_Clothing', 'category_Electronics', 'category_Games',
#        'category_Other', 'category_Outdoors', 'category_Smartphones',
#        'device_type_Mobile', 'device_type_PC', 'device_type_Tablet'],
#       dtype='object')

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Scale the numeric columns
scaled_cat = scaler.fit_transform(x_cat)

# %%
scaled_cat
# Out:
# array([[-0.24271229, -0.32322742, -0.19543554, ..., -0.40966337,
#         -1.89376969,  3.55459353],
#        [-1.08746076, -1.0471347 , -1.24782744, ..., -0.40966337,
#         -1.89376969,  3.55459353],
#        [ 0.43954391,  0.41196441,  0.70652517, ..., -0.40966337,
#          0.52804732, -0.28132612],
#        ...,
#        [ 0.70337104,  0.62275272, -1.38736439, ..., -0.40966337,
#          0.52804732, -0.28132612],
#        [ 1.06349254,  1.01027712, -1.53434981, ..., -0.40966337,
#         -1.89376969,  3.55459353],
#        [ 2.97826913,  3.15587176, -1.57604731, ..., -0.40966337,
#          0.52804732, -0.28132612]])

# %%
# Split the data into training and testing sets
train_x_cat, test_x_cat, train_y_cat, test_y_cat = train_test_split(scaled_cat, y_cat, test_size=0.25, random_state=42)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# Initialize the Logistic Regression model
model = LogisticRegression()

# Train (fit) the model on the training data
model.fit(train_x_cat, train_y_cat)

# Make predictions on the test data
y_pred = model.predict(test_x_cat)

# %%
# Create an accuracy classification table
confusion = confusion_matrix(test_y_cat, y_pred)
accuracy = accuracy_score(test_y_cat, y_pred)

# %%
confusion
# Out:
# array([[135,  19],
#        [ 89,  10]])

# %%
# Visualize the accuracy classification table
fig, ax = plt.subplots()
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues', ax=ax)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title('Accuracy Classification Table')
plt.show()

# %%
# Calculate the percentage of error in predictions
error_percentage = 100 * (1 - accuracy)

# Print accuracy and error percentage
print(f"Accuracy: {accuracy:.2f}")
print(f"Percentage of Error: {error_percentage:.2f}%")
# Out:
# Accuracy: 0.57
# Percentage of Error: 42.69%

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Initialize the Decision Tree Classifier model
model_decTree = DecisionTreeClassifier()

# Train (fit) the model on the training data
model_decTree.fit(train_x_cat, train_y_cat)

# Make predictions on the test data
y_pred_decTree = model_decTree.predict(test_x_cat)

# %%
# Create an accuracy classification table
confusion_decTree = confusion_matrix(test_y_cat, y_pred_decTree)
accuracy_decTree = accuracy_score(test_y_cat, y_pred_decTree)

# %%
# Visualize the accuracy classification table
fig, ax = plt.subplots()
sns.heatmap(confusion_decTree, annot=True, fmt='d', cmap='Blues', ax=ax)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title('Accuracy Classification Table for DecTree')
plt.show()

# %%
# Calculate the percentage of error in predictions
error_percentage_decTree = 100 * (1 - accuracy_decTree)

# Print accuracy and error percentage
print(f"Accuracy: {accuracy_decTree:.2f}")
print(f"Percentage of Error: {error_percentage_decTree:.2f}%")
# Out:
# Accuracy: 0.55
# Percentage of Error: 45.06%

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Initialize the Random Forest Classifier model
model_rfcl = RandomForestClassifier()

# Train (fit) the model on the training data
model_rfcl.fit(train_x_cat, train_y_cat)

# Make predictions on the test data
y_pred_rfcl = model_rfcl.predict(test_x_cat)

# %%
# Create an accuracy classification table
confusion_rfcl = confusion_matrix(test_y_cat, y_pred_rfcl)
accuracy_rfcl = accuracy_score(test_y_cat, y_pred_rfcl)

# %%
# Visualize the accuracy classification table
fig, ax = plt.subplots()
sns.heatmap(confusion_rfcl, annot=True, fmt='d', cmap='Blues', ax=ax)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title('Accuracy Classification Table for Rfcl')
plt.show()

# %%
# Calculate the percentage of error in predictions
error_percentage_rfcl = 100 * (1 - accuracy_rfcl)

# Print accuracy and error percentage
print(f"Accuracy: {accuracy_rfcl:.2f}")
print(f"Percentage of Error: {error_percentage_rfcl:.2f}%")
# Out:
# Accuracy: 0.57
# Percentage of Error: 42.69%

# %% [markdown]
# # KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Set a range of K values to test
k_values = list(range(1, 11))

# Initialize lists to store accuracy results
accuracy_results = []

# Iterate through different values of K
for k in k_values:
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(train_x_cat, train_y_cat)
    y_pred = model.predict(test_x_cat)
    accuracy = accuracy_score(test_y_cat, y_pred)
    accuracy_results.append(accuracy)

# Create a line plot to visualize the accuracy rate based on the number of Ks used
plt.plot(k_values, accuracy_results, marker='o')
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Accuracy')
plt.title('KNN Classifier Accuracy vs. K')
plt.show()

# %%
# Initialize the KNN Classifier model with the chosen K
best_k = 2
model_KNN = KNeighborsClassifier(n_neighbors=best_k)
model_KNN.fit(train_x_cat, train_y_cat)
y_pred_KNN = model_KNN.predict(test_x_cat)

# %%
# Create an accuracy classification table
confusion_KNN = confusion_matrix(test_y_cat, y_pred_KNN)
accuracy_KNN = accuracy_score(test_y_cat, y_pred_KNN)

# %%
# Visualize the accuracy classification table
fig, ax = plt.subplots()
sns.heatmap(confusion_KNN, annot=True, fmt='d', cmap='Blues', ax=ax)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title('Accuracy Classification Table for KNN')
plt.show()

# %%
# Calculate the percentage of error in predictions
error_percentage_KNN = 100 * (1 - accuracy_KNN)

# Print accuracy and error percentage
print(f"Accuracy: {accuracy_KNN:.2f}")
print(f"Percentage of Error: {error_percentage_KNN:.2f}%")
# Out:
# Accuracy: 0.58
# Percentage of Error: 42.29%

# %% [markdown]
# # LightGBM Classifier

# %%
import lightgbm as lgb

# %%
# Create LightGBM datasets from NumPy arrays
train_data = lgb.Dataset(train_x_cat, label=train_y_cat)

# Define LightGBM parameters (customize as needed)
params = {
    "objective": "binary",
    "metric": "binary_logloss",
    "boosting_type": "gbdt",
    "num_leaves": 31,
    "learning_rate": 0.05,
}

# Train the LightGBM model
model = lgb.train(params, train_data, num_boost_round=100)

# Make predictions on the test data
y_pred_prob = model.predict(test_x_cat)
y_pred_light = (y_pred_prob >= 0.5).astype(int)
# Out:
# [LightGBM] [Info] Number of positive: 281, number of negative: 475
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000952 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 870
# [LightGBM] [Info] Number of data points in the train set: 756, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.371693 -> initscore=-0.524960
# [LightGBM] [Info] Start training from score -0.524960
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
# Create an accuracy classification table
confusion_light = confusion_matrix(test_y_cat, y_pred_light)
accuracy_light = accuracy_score(test_y_cat, y_pred_light)

# %%
# Visualize the accuracy classification table
fig, ax = plt.subplots()
sns.heatmap(confusion_light, annot=True, fmt='d', cmap='Blues', ax=ax)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title('Accuracy Classification Table for KNN')
plt.show()

# %%
# Calculate the percentage of error in predictions
error_percentage_light = 100 * (1 - accuracy_light)

# Print accuracy and error percentage
print(f"Accuracy: {accuracy_light:.2f}")
print(f"Percentage of Error: {error_percentage_light:.2f}%")
# Out:
# Accuracy: 0.56
# Percentage of Error: 43.87%
